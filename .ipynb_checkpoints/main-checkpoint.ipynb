# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.metrics import classification_report, RocCurveDisplay, ConfusionMatrixDisplay
from sklearn.base import clone 
from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline
# %matplotlib inline
import warnings
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from matplotlib import colors
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %% [markdown]
# # Data Processing

# %% [markdown]
# ### Open Data

# %%
data = pd.read_csv('./dataset/train.csv')
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Describe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.3 KB

# %%
# Check for missing and duplicated values
print(data.isnull().sum())
print(data.duplicated().sum())
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64
# 0

# %% [markdown]
# - This dataset contains information from 2000 mobile phones.
#  - We have 21 variables including 20 independent variables and 1 dependent variable which is price_range.
# - There is no missing value in the dataset.
# - We have 8 categorical variables: n_cores , price_range, blue, dual_sim, four_g, three_g, touch_screen, wifi
# - We have 13 numeric variables: battery_power, clock_speed, fc, int_memory, m_dep, mobile_wt, pc, px_height, px_width, ram, talk_time, sc_h, sc_w

# %% [markdown]
# ### Statistical Description of Categorical Variables

# %%
# Filter out categorical features
data_categorical = data[['price_range', 'n_cores', 'blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']].astype(str)

# Calculate number of unique values and unique values for each feature
unique_counts = data_categorical.nunique()
unique_values = data_categorical.apply(lambda x: x.unique())

# Create new dataframe with the results
pd.DataFrame({'Number of Unique Values': unique_counts, 'Unique Values': unique_values})
# Out:
#               Number of Unique Values             Unique Values
# price_range                         4              [1, 2, 3, 0]
# n_cores                             8  [2, 3, 5, 6, 1, 8, 4, 7]
# blue                                2                    [0, 1]
# dual_sim                            2                    [0, 1]
# four_g                              2                    [0, 1]
# three_g                             2                    [0, 1]
# touch_screen                        2                    [0, 1]
# wifi                                2                    [1, 0]

# %% [markdown]
# ### Statistical Description of Numerical Variables

# %%
# Filter out numerical features
data_numerical = data.drop(data_categorical.columns, axis=1)
# Generate descriptive statistics
data_numerical.describe().T.round(1)
# Out:
#                 count    mean     std    min     25%     50%     75%     max
# battery_power  2000.0  1238.5   439.4  501.0   851.8  1226.0  1615.2  1998.0
# clock_speed    2000.0     1.5     0.8    0.5     0.7     1.5     2.2     3.0
# fc             2000.0     4.3     4.3    0.0     1.0     3.0     7.0    19.0
# int_memory     2000.0    32.0    18.1    2.0    16.0    32.0    48.0    64.0
# m_dep          2000.0     0.5     0.3    0.1     0.2     0.5     0.8     1.0
# mobile_wt      2000.0   140.2    35.4   80.0   109.0   141.0   170.0   200.0
# pc             2000.0     9.9     6.1    0.0     5.0    10.0    15.0    20.0
# px_height      2000.0   645.1   443.8    0.0   282.8   564.0   947.2  1960.0
# px_width       2000.0  1251.5   432.2  500.0   874.8  1247.0  1633.0  1998.0
# ram            2000.0  2124.2  1084.7  256.0  1207.5  2146.5  3064.5  3998.0
# sc_h           2000.0    12.3     4.2    5.0     9.0    12.0    16.0    19.0
# sc_w           2000.0     5.8     4.4    0.0     2.0     5.0     9.0    18.0
# talk_time      2000.0    11.0     5.5    2.0     6.0    11.0    16.0    20.0

# %% [markdown]
# ## Visualization

# %%
display(data.shape)
display(data["price_range"].value_counts())
sns.countplot(x='price_range', data=data)
# Out:
# (2000, 21)
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64
# <Axes: xlabel='price_range', ylabel='count'>

# %%
# Exploratory Data Analysis 
binary_features = [col for col in data.columns if data[col].nunique() == 2]
numeric_features = [col for col in data.select_dtypes(include=[np.number]).columns if col not in binary_features and col != 'price_range']
print(binary_features)
print(numeric_features)
for column in data[numeric_features]:
    if column != 'price_range':
        plt.figure(figsize=(10, 4))
        data.boxplot(column=column, by='price_range')
        plt.title(f'Boxplot of Price by {column}')
        plt.show()
# Out:
# ['blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']
# ['battery_power', 'clock_speed', 'fc', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time']

# %% [markdown]
# ### Noise Dectection
#     As seen px_height (Pixel Resolution Height) and sc_w (Screen Width of mobile in cm) contain many values of zero and close to zero, which look like noise

# %%
def show_noise (data):
    sns.set(rc = {'axes.labelsize' : 15})               
    fig, ax = plt.subplots(1, 2, figsize=(15,5), dpi=120)
    
    
    # Plot px_height histogram:
    _, bin_edges = np.histogram(data['px_height'], range=(np.floor(data['px_height'].min()), np.ceil(data['px_height'].max())))                                     
    graph1 = sns.histplot(x='px_height', data=data, bins=bin_edges, color='orangered', ax=ax[0])
    ax[0].set_xticks(bin_edges)
    ax[0].set_title('px_height Distributuion', fontsize=20) 
    for cont in graph1.containers:
            graph1.bar_label(cont)
    
    # Plot sc_w histogram:
    _, bin_edges = np.histogram(data['sc_w'], range=(np.floor(data['sc_w'].min()), np.ceil(data['sc_w'].max())))
    graph2 = sns.histplot(x='sc_w', data=data, bins=bin_edges, color='orangered', ax=ax[1])
    ax[1].set_xticks(bin_edges)
    ax[1].set_title('sc_w Distributuion', fontsize=20)      
    for cont in graph2.containers:
            graph2.bar_label(cont)
            
    plt.tight_layout()
    plt.show()
show_noise(data)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Detect Noise values in sc_w 
sc_w_NoiseIndex = data[data['sc_w'] < 2].index

# Detect Noise values in px_height
px_height_NoiseIndex = data[data['px_height'] < 5].index

print('The number of detected noise values for sc_w: ', len(sc_w_NoiseIndex))
print('The number of detected noise values for px_height: ', len(px_height_NoiseIndex))
# Out:
# The number of detected noise values for sc_w:  390
# The number of detected noise values for px_height:  9

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# #### Handle Missing values

# %% [markdown]
# #### Handle Noise values ( KNN imputer)

# %% [markdown]
# KNN Imputer:
# KNN Imputer is a machine learning technique used to impute or fill in missing values and noise values in a dataset. The technique works by finding the k-nearest neighbors of a data point with missing values and then imputing the missing values with the average of those neighbors.

# %%
# Make a copy of dataset
data_denoised = data_denoised.copy()

# Replace the noise values with NaN
data_denoised.loc[sc_w_NoiseIndex,'sc_w'] = np.nan
data_denoised.loc[px_height_NoiseIndex,'px_height'] = np.nan

# Create a KNN imputer object with k=2
imputer = KNNImputer(n_neighbors=2)

# Impute the noise values
imputed_data = imputer.fit_transform(data_denoised)

# Convert array to dataframe
data_denoised = pd.DataFrame(imputed_data, columns=data_denoised.columns)

# Define the features (X) and the output labels (y)
X_denoised = data_denoised.drop('price_range', axis=1)
data_denoised['price_range'] = data_denoised['price_range'].astype(int)
y = data_denoised['price_range'] 

show_noise(data_denoised)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Models

# %% [markdown]
# ## Define Functions for using later

# %% [markdown]
# ### Define a function that finds the optimal combination of hyperparameters to achieve the best accuracy for our classifier. The function uses GridSearchCV and cross-validation (StratifiedKFold) to evaluate different combinations of hyperparameters, and selects the combination with the highest accuracy

# %%
def tune_hyperparameters(clf, param_grid, X_train, y_train):
    # Create the cross-validation object using StratifiedKFold to ensure the class distribution is the same across all the folds
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    # Create the GridSearchCV object
    # GridSearVC with cross-validation (5 folds)
    clf_grid = GridSearchCV(clf, param_grid, cv=cv, scoring='accuracy', n_jobs=-1, return_train_score=True)
    
    # Fit the GridSearchCV object to the training data
    clf_grid.fit(X_train, y_train)
    
    # Extract all accuracy scores and their corresponding hyperparameters
    results = clf_grid.cv_results_
    all_accuracies = results['mean_test_score']
    all_params = results['params']
    
    # Combine the parameters and accuracies into a list of dictionaries for better readability
    accuracies_with_params = [{'params': params, 'accuracy': accuracy} for params, accuracy in zip(all_params, all_accuracies)]
    
    # Print all accuracy scores with their corresponding hyperparameters
    for item in accuracies_with_params:
        print(f"Hyperparameters: {item['params']}, Accuracy: {item['accuracy']:.4f}")

    # Get the best hyperparameters
    print("Best hyperparameters:\n", clf_grid.best_params_)
    
    # Return best_estimator_ attribute which gives us the best model that has been fitted to the training data
    return clf_grid.best_estimator_

# %% [markdown]
# ### Define Drop-column Feature Importances

# %%
def drop_column_importance(model, X_train, y_train, random_state=0):
    # list containing feature importances
    importances = []
    # Clone the model
    model_clone = clone(model)
    # Set random_state for comparability
    model_clone.random_state = random_state
    # Train the model
    model_clone.fit(X_train, y_train)
    # Create the cross-validation object using StratifiedKFold 
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
    # Score the benchmark model using cross-validation
    benchmark_score = cross_val_score(model_clone, X_train, y_train, cv=cv, scoring='accuracy').mean()

    
    # Iterate over all features and store feature importance
    for col in X_train.columns:
        # Clone the model
        model_clone = clone(model)
        # Set random_state for comparability
        model_clone.random_state = random_state
        # Traint the model on the the dataset with a single feature removed
        model_clone.fit(X_train.drop(col, axis = 1), y_train)
        # Score the droped-column model
        drop_column_score = cross_val_score(model_clone, X_train.drop(col,axis=1), y_train, cv=cv, scoring='accuracy').mean()
        # Store feature importance which is defined as the difference between the benchmark and the new model score
        importances.append(benchmark_score - drop_column_score)
        
    # Return the features along with their importances in the form of a dataframe
    importances_df = pd.DataFrame({'feature': X_train.columns, 'feature importance': importances}) \
                     .sort_values('feature importance', ascending = False).reset_index(drop = True)
           
    return importances_df

# %% [markdown]
# ### Define a function to visualize the results of Drop-column Feature Importance technique using bar charts:

# %%
def drop_column_importance_plot(model, X_train, y_train):
    
    # Call drop-column feature importance function
    df_drop_column = drop_column_importance(model, X_train, y_train, random_state=0)
    # Rename columns
    df_drop_column.columns = ['Feature', 'Feature Importance']
    
    # Plot barchart
    plt.figure(figsize=(12,10))
    sns.barplot(data=df_drop_column, x='Feature Importance', y='Feature', orient='h', color='orangered')
    plt.title('Drop Column Feature Importance', fontsize=20)
    plt.show()

# %% [markdown]
# ## SVC
# ### Pine line 1:
#     1. StandardScaler
#     2. Hyperparameter Tunning with GridSearchCV (cross-validation (5 folds))
#     3. Support Vector Classifier (SVC)

# %% [markdown]
# ### Scale Data using Standard Scaler

# %% [markdown]
# #### Define the features (X) and the output labels (y) of the given dataset:

# %%
X = data.drop('price_range', axis=1)
y = data['price_range']

# %% [markdown]
# #### Perform train test split:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)
X_train.head()
y_train.head()
# Out:
# 538     2
# 1094    0
# 1654    0
# 8       0
# 1256    3
# Name: price_range, dtype: int64

# %% [markdown]
# #### Scale data using StandardScaler:

# %%
# Scale the training and test data using Standard Scaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)
# Convert training and test sets from numpy array to pandas dataframes
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns)
X_train.head()
X_test.head()
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0       1.365232  0.995012     0.119198  1.010051 -0.342193 -1.128152
# 1       0.436537  0.995012     1.531918  1.010051 -1.042929 -1.128152
# 2      -1.127817  0.995012    -1.293522  1.010051 -0.342193  0.886405
# 3       1.056418  0.995012    -1.293522 -0.990050  2.694331 -1.128152
# 4      -0.598101  0.995012    -1.293522 -0.990050  2.460752 -1.128152
#
#    int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0   -0.311507 -1.371891  -0.198945  0.653335  0.913804  -0.493071 -0.267954
# 1   -0.642019  0.345119   1.127835  0.198841 -1.643409  -1.019416 -0.128258
# 2   -0.256422 -1.371891  -0.833492  0.198841 -0.045151  -1.295341 -0.950135
# 3   -0.586933 -1.371891   0.435602 -0.255653  1.553107  -1.195637 -0.361084
# 4    1.175795  1.718727  -0.285474  1.562323  1.393281  -0.750447 -1.399489
#
#         ram      sc_h      sc_w  talk_time   three_g  touch_screen  wifi
# 0  0.889225 -1.702370 -1.243335   1.271968 -1.969276           1.0  -1.0
# 1  0.481466  0.722658 -1.243335   1.454854  0.507801          -1.0  -1.0
# 2  1.377792 -0.732359 -0.322772   0.723312  0.507801           1.0  -1.0
# 3 -0.890423  0.965161 -1.243335   1.271968  0.507801           1.0  -1.0
# 4  1.009973 -0.004850  0.137509  -0.556886  0.507801          -1.0  -1.0

# %% [markdown]
# ### SVM Hyperparameter Tuning

# %%
param_grid = {'kernel': ['linear'],
               'C': [ 0.1, 1, 10, 50, 100]
             }

# %%
# Create a SVC object
svm = SVC(probability=True, random_state=0)

# Find the best classifier with the optimal hyperparameters
svm_optimized = tune_hyperparameters(svm, param_grid, X_train, y_train)
# Out:
# Hyperparameters: {'C': 0.1, 'kernel': 'linear'}, Accuracy: 0.9369
# Hyperparameters: {'C': 1, 'kernel': 'linear'}, Accuracy: 0.9587
# Hyperparameters: {'C': 10, 'kernel': 'linear'}, Accuracy: 0.9644
# Hyperparameters: {'C': 50, 'kernel': 'linear'}, Accuracy: 0.9675
# Hyperparameters: {'C': 100, 'kernel': 'linear'}, Accuracy: 0.9638
# Best hyperparameters:
#  {'C': 50, 'kernel': 'linear'}

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### Define Evaluation Function

# %%
orangered_cmap = LinearSegmentedColormap.from_list('orangered', ['#FFECEC','orangered'])
def metrics_calculator(clf, X_test, y_test, model_name):

    y_pred = clf.predict(X_test)
    result = pd.DataFrame(data=[accuracy_score(y_test, y_pred),
                                precision_score(y_test, y_pred, average='macro'),
                                recall_score(y_test, y_pred, average='macro'),
                                f1_score(y_test, y_pred, average='macro')],
                          index=['Accuracy','Macro Precision','Macro Recall','Macro F1-score'],
                          columns = [model_name])
    
    result = (result * 100).round(2).astype(str) + '%'                            
    return result

# %%
def model_evaluation(clf, X_train, X_test, y_train, y_test, model_name):

    # Set font scale
    sns.set(font_scale=1.5)
    
    # Generate classification report for training set
    y_pred_train = clf.predict(X_train)
    print("\n\t  Classification report for training set")
    print("-"*55)
    print(classification_report(y_train, y_pred_train))

    # Generate classification report for test set
    y_pred_test = clf.predict(X_test)
    print("\n\t   Classification report for test set")
    print("-"*55)
    print(classification_report(y_test, y_pred_test))
    print('\n')
    
    # Create figure and subplots 
    fig, (ax1, ax2) = plt.subplots(1, 2, dpi=90, figsize=(12, 5))
    
    
    # Report desired results as a summary in the form of a table
    result = metrics_calculator(clf, X_test, y_test, model_name)
    table = ax1.table(cellText=result.values, colLabels=result.columns, rowLabels=result.index, loc='center')
    table.scale(0.6, 4.2)
    table.set_fontsize(12)
    ax1.axis('tight')
    # Hide the axes
    ax1.axis('off')
    # set the title
    ax1.set_title('{} Performance Summary on Test Data'.format(model_name), fontsize=18)
    # Modify color 
    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_color('orangered')
              
    # Plot confusion matrix for test set
    ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test, colorbar=False, cmap=orangered_cmap, ax=ax2)
    ax2.set_title('Confusion Matrix for Test Data')                                     
    ax2.grid(False)
            
    plt.tight_layout()
    plt.show()

# %%
model_evaluation(svm_optimized, X_train, X_test, y_train, y_test, 'SVM')
# Out:
# 	  Classification report for training set
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       400
#            1       0.98      0.97      0.98       400
#            2       0.98      0.98      0.98       400
#            3       0.99      0.99      0.99       400
#
#     accuracy                           0.99      1600
#    macro avg       0.99      0.99      0.99      1600
# weighted avg       0.99      0.99      0.99      1600
#
#
# 	   Classification report for test set
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       100
#            1       0.99      0.96      0.97       100
#            2       0.97      0.98      0.98       100
#            3       0.99      0.98      0.98       100
#
#     accuracy                           0.98       400
#    macro avg       0.98      0.98      0.98       400
# weighted avg       0.98      0.98      0.98       400

# %%
# Save the final performance of SVM classifier
svm_result = metrics_calculator(svm_optimized, X_test, y_test, 'SVM')

# %% [markdown]
# ## Decision Tree
# ### Pipeline 2:
#     1. Hyperparameter Tuning with GridSearchCV (cross-validation (5 folds))
#     2. Drop unnecessary features
#     3. Apply Decision Tree classifier

# %% [markdown]
# #### Hyperparameter Tuning

# %%
# Define the hyperparameter grid
param_grid = {'criterion': ['gini', 'entropy', 'log_loss'],
              'max_depth': np.arange(1, 15),
              'min_samples_split': np.arange(2, 10),
              'min_samples_leaf': np.arange(1, 10),
              'max_features': [None, 'sqrt', 'log2']} 
# Perform train test split
X_train, X_test, y_train, y_test = train_test_split(X_denoised, y, test_size=0.2, random_state=0, stratify=y)

# Create a  Decision Tree Classifier object
dt = DecisionTreeClassifier(random_state=0)

# Find the best classifier with the optimal hyperparameters
dt_optimized = tune_hyperparameters(dt, param_grid, X_train, y_train)
# Out:
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 2}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 3}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 4}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 5}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 6}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 7}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 8}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 9}, Accuracy: 0.4987
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 2}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 3}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 4}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 5}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 6}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 7}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 8}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 9}, Accuracy: 0.3162
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 7, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 2}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 3}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 4}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 5}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 6}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 7}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 8}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 9, 'min_samples_split': 9}, Accuracy: 0.7394
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 6}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 7}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 9}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 7}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 9}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 3}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 6}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 7}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 8}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 9}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 3}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 6}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 7}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 9}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 4}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 7}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 8}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 9}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 3}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 5}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 6}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 7}, Accuracy: 0.4306
# Hyperparameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 8}, Accuracy: 0.4306
# ...
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 8}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 9}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 3}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 4}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 5}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 6}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 7}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 8}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 9}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 2}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 3}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 4}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 5}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 6}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 7}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 8}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 9}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 6}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 7}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 9}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 2}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 3}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 4}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 5}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 6}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 7}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 8}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 9}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}, Accuracy: 0.6863
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3}, Accuracy: 0.6906
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4}, Accuracy: 0.6969
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}, Accuracy: 0.7294
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 6}, Accuracy: 0.6944
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 7}, Accuracy: 0.6856
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8}, Accuracy: 0.6919
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 9}, Accuracy: 0.6988
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}, Accuracy: 0.6869
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 3}, Accuracy: 0.6869
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4}, Accuracy: 0.6869
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}, Accuracy: 0.6369
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 6}, Accuracy: 0.6781
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 7}, Accuracy: 0.6725
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8}, Accuracy: 0.7269
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 9}, Accuracy: 0.6975
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 2}, Accuracy: 0.6675
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 3}, Accuracy: 0.6675
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 4}, Accuracy: 0.6675
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 5}, Accuracy: 0.6675
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 6}, Accuracy: 0.6675
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 7}, Accuracy: 0.7025
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 8}, Accuracy: 0.7100
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 9}, Accuracy: 0.6775
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}, Accuracy: 0.7162
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 3}, Accuracy: 0.7162
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4}, Accuracy: 0.7162
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}, Accuracy: 0.7162
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 6}, Accuracy: 0.7162
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 7}, Accuracy: 0.7162
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8}, Accuracy: 0.7162
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 9}, Accuracy: 0.6706
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 4}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 6}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 7}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 8}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 9}, Accuracy: 0.7188
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 2}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 3}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 4}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 5}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 6}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 7}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 8}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 6, 'min_samples_split': 9}, Accuracy: 0.6381
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 2}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 3}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 4}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 5}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 6}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 7}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 8}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 7, 'min_samples_split': 9}, Accuracy: 0.6475
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 6}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 7}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 9}, Accuracy: 0.6537
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 2}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 3}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 4}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 5}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 6}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 7}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 8}, Accuracy: 0.6887
# Hyperparameters: {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 9}, Accuracy: 0.6887
# Best hyperparameters:
#  {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 8}

# %% [markdown]
# #### Drop Unnecessary Columns

# %%
drop_column_importance_plot(dt_optimized, X_train, y_train)
# Find Important features with positive feature_importance value
feature_importances = drop_column_importance(dt_optimized, X_train, y_train, 0)
selected_features = feature_importances[feature_importances['feature importance']>0.01]['feature']  # Threshold value of 0.01

# Filter dataset
X_train = X_train[selected_features]
X_test = X_test[selected_features]

# %%
pd.DataFrame(selected_features)
# Out:
#          feature
# 0            ram
# 1  battery_power
# 2       px_width
# 3      px_height

# %% [markdown]
# #### Apply Decision Tree classifier

# %%
print(dt_optimized)
model_evaluation(dt_optimized, X_train, X_test, y_train, y_test, 'haha')
# Out:
# DecisionTreeClassifier(max_depth=9, min_samples_leaf=3, min_samples_split=8,
#                        random_state=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[279], line 2
#       1 print(dt_optimized)
# ----> 2 model_evaluation(dt_optimized, X_train, X_test, y_train, y_test, 'haha')
#
# Cell In[278], line 7, in model_evaluation(clf, X_train, X_test, y_train, y_test, model_name)
#       4 sns.set(font_scale=1.5)
#       6 # Generate classification report for training set
# ----> 7 y_pred_train = clf.predict(X_train)
#       8 print("\n\t  Classification report for training set")
#       9 print("-"*55)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/tree/_classes.py:426, in BaseDecisionTree.predict(self, X, check_input)
#     403 """Predict class or regression value for X.
#     404
#     405 For a classification model, the predicted class for each sample in X is
#    (...)
#     423     The predicted classes, or the predict values.
#     424 """
#     425 check_is_fitted(self)
# --> 426 X = self._validate_X_predict(X, check_input)
#     427 proba = self.tree_.predict(X)
#     428 n_samples = X.shape[0]
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/tree/_classes.py:392, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     390 """Validate the training data on predict (probabilities)."""
#     391 if check_input:
# --> 392     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     393     if issparse(X) and (
#     394         X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     395     ):
#     396         raise ValueError("No support for np.int64 index based sparse matrices")
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:548, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     483 def _validate_data(
#     484     self,
#     485     X="no_validation",
#    (...)
#     489     **check_params,
#     490 ):
#     491     """Validate input data and set or check the `n_features_in_` attribute.
#     492
#     493     Parameters
#    (...)
#     546         validated.
#     547     """
# --> 548     self._check_feature_names(X, reset=reset)
#     550     if y is None and self._get_tags()["requires_y"]:
#     551         raise ValueError(
#     552             f"This {self.__class__.__name__} estimator "
#     553             "requires y to be passed, but the target y is None."
#     554         )
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:481, in BaseEstimator._check_feature_names(self, X, reset)
#     476 if not missing_names and not unexpected_names:
#     477     message += (
#     478         "Feature names must be in the same order as they were in fit.\n"
#     479     )
# --> 481 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - blue
# - clock_speed
# - dual_sim
# - fc
# - four_g
# - ...

# %% [markdown]
# # Metrics

# %% [markdown]
# # Evaluations
